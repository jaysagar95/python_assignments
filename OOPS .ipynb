# %% [markdown]
# Q1 Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of ​​the rectangle.Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class.Create a Parallelepipede child class inheriting from the Rectangle class and with a height attribute and another Volume() method to calculate the volume of the Parallelepiped.

# %%
class Rectangle:
  def length(rect):
    rect.length=int(input("Enter length of rectangle"))
  def width(rect):
    rect.width=int(input("Enter width of rectangle"))
  def area(rect):
    rect.area=rect.length*rect.width
    print("The area of rectangle is",rect.area)
  def peri(rect):
    print("The perimeter of rectangle is ",2*(rect.length+rect.width))  
class Parallelopipede(Rectangle):
  def height(rect):
    rect.height=int(input("Enter the height of parallelopipede"))
  def volume(rect):
    print("the volume of rect is",rect.area*rect.height)

# %%
r1=Parallelopipede()
r1.length()
r1.width()
r1.area()
r1.peri()
# Out:
# Enter length of rectangle50
# Enter width of rectangle40
# The area of rectangle is 2000
# The perimeter of rectangle is  180

# %%
r1.height()
r1.volume()
# Out:
# Enter the height of parallelopipede20
# the volume of rect is 40000

# %% [markdown]
# Q2 Create a Python class Person with attributes: name and age of type string.Create a display() method that displays the name and age of an object created via the Person class.Create a child class Student  which inherits from the Person class and which also has a section attribute.Create a method displayStudent() that displays the name, age and section of an object created via the Student class.Create a student object via an instantiation on the Student class and then test the displayStudent method.

# %%
class Person:
  def getname(self):
    self.name=input("Enter the name")
  def getage(self):
    self.age=int(input("Enter the age"))

# %%
class Student(Person):
  def name1(self):
    self.name1=input("Enter the name of student")
  def age1(self):
    self.age1=int(input("Enter the age of student"))
  def displaystudent(self):
    print("The name of parant is",self.name,"and age is",self.age,"The name of student is",self.name1,"and age is ",self.age1)

# %%
s=Student()

# %%
s.getname()
s.getage()
s.name1()
s.age1()
s.displaystudent()
# Out:
# Enter the nameRahul
# Enter the age48
# Enter the name of studentJay
# Enter the age of student25
# The name of parant is Rahul and age is 48 The name of student is Jay and age is  25

# %% [markdown]
# Q3 Create a Python class called BankAccount which represents a bank account, having as attributes: accountNumber (numeric type), name (name of the account owner as string type), balance.Create a constructor with parameters: accountNumber, name, balance.Create a Deposit() method which manages the deposit actions.Create a Withdrawal() method  which manages withdrawals actions.Create an bankFees() method to apply the bank fees with a percentage of 5% of the balance account.Create a display() method to display account details.Give the complete code for the  BankAccount class.

# %%
class BankAccount:
  def __init__(self,no="123",name="unknown"):
    self.no=(input("Enter the acc no"))
    self.name=input("Enter the name of acc holder")
    while True:
      self.balance=int(input("Enter the balance"))
      if int(self.balance) >2000:
        break
      else:
        print("Enter valid balance") 
    print("acc no",self.no,"having name",self.name,"having a balance of",self.balance)


  def deposit(self):
    while True:
      self.deposit=float(input("Enter the deposit amount"))
      if self.deposit > 0:
        self.newbalance=self.balance+self.deposit
        break
      else:
        print("Dear Customer, your withdrawal amount must be less than",0)
    print("Your current balance is",self.newbalance)  


  def withdraw(self):
     while True:
       self.withdraw=float(input("Enter the withdraw amount"))
       if self.withdraw < self.newbalance:
         self.baw=self.newbalance-self.withdraw
         break
       else:
         print("Dear customer please enter valid amount")  
     print("Dear customer, your balance after withdrawl is ",self.baw) 


  def bf(self):
     self.bf= 0.05*self.baw
     self.cb=self.baw-self.bf
     print("Dear customer, your balance after deducing our bank fees is ",self.cb) 

  def details(self):
    print("account name =",self.name,
          "account no=",self.no,
          "initial balance",self.balance,
          "balance after deposit",self.newbalance,
          "balance after withdraw",self.baw,
          "banlance after deducting bank fees",self.cb)

# %%
p=BankAccount()
p.deposit()
p.withdraw()
p.bf()
p.details()
# Out:
# Enter the acc no123456
# Enter the name of acc holderJay Sagar
# Enter the balance100000
# acc no 123456 having name Jay Sagar having a balance of 100000
# Enter the deposit amount20000
# Your current balance is 120000.0
# Enter the withdraw amount20000
# Dear customer, your balance after withdrawl is  100000.0
# Dear customer, your balance after deducing our bank fees is  95000.0
# account name = Jay Sagar account no= 123456 initial balance 100000 balance after deposit 120000.0 balance after withdraw 100000.0 banlance after deducting bank fees 95000.0

# %% [markdown]
# Q5 Create a child class Bus that will inherit all of the variables and methods of the Vehicle class. In the vehicle class create relevant methods and variables.
#
#
# 2. Define a property that must have the same value for every class instance (object). Define a class attribute "color” with a default value white. I.e., Every Vehicle should be white.

# %%
class Vehicle:
  def __init__(self,color='white'):
    self.name=input("Enter the name of manufacturer  ")
    self.wheel=int(input("Enter the no of wheels  "))
    self.typeoffuel=input("Enter the type of fuel ")
    self.color='white'
class Bus(Vehicle):
  def b(self):
    self.mode=input("Enter the mode of ac or non-ac  ")

  def Details(self):
    print("Name of manufacturer is",self.name,"no of wheels is",self.wheel,"and type of fuel is",self.typeoffuel,"and color is",self.color,"along with type of",self.mode)

# %%
v=Bus()
v.b()
v.Details()
# Out:
# Enter the name of manufacturer  Mahendra
# Enter the no of wheels  12
# Enter the type of fuel Diesel
# Enter the mode of ac or non-ac  AC
# Name of manufacturer is Mahendra no of wheels is 12 and type of fuel is Diesel and color is white along with type of AC

# %% [markdown]
#  Define a Book class with the following attributes: Title, Author (Full name), Price.Define a constructor used to initialize the attributes of the method with values entered by the user.Set the View() method to display information for the current book.Write a program to testing the Book class.

# %%
class Book:
  def __init__(self):
    self.Title=input("Enter the Title of the book  ")
    self.Author=input("Enter the name of Author  ")
    self.Price=int(input("Enter the price of book  "))
  def Details(self):
    print("Title of the book is",self.Title,"name of Author is",self.Author,"and the price of book is ",self.Price)

# %%
b=Book()
b.Details()
# Out:
# Enter the Title of the book  SHREEMAN YOGI
# Enter the name of Author  RANJEET DESAI
# Enter the price of book  550
# Title of the book is SHREEMAN YOGI name of Author is RANJEET DESAI and the price of book is  550
